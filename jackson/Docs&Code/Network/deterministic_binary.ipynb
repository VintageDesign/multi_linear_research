# %%
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import numpy.linalg as la

from matplotlib.animation import FuncAnimation

# %%
def make_sym(A):
    tmp = np.triu(A)
    return tmp + tmp.T

N = 200
n = 10
period = 20
offset = 2
tensor = np.zeros((N,n,n))
num_elem = n*(n-1)//2
xs, ys = np.triu_indices(n, k=1)
shift = np.zeros((n, n))
for i in range(num_elem):
    shift[xs[i],ys[i]] = -i*offset
for i in range(N):
    tmp = np.sin(i*((2*np.pi)/period) + shift)
    tmp = np.triu(tmp,k=1)
    tmp = tmp + tmp.T
    tmp = (tmp+1)/2
    np.fill_diagonal(tmp, 0)
    tensor[i] = np.round(tmp)
#tensor += np.random.normal(loc=0.5, scale=0.091, size=(N, n, n))

# %%
plt.figure(figsize=(10, 10))
for i in range(5):
    plt.subplot(5,1,i+1)
    plt.plot(tensor[:,xs[i],ys[i]])

# %%
norm = np.array([la.norm(adj) for adj in tensor])
plt.plot(np.arange(len(tensor)), norm)

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,2,i+1)
    plt.imshow(tensor[i])

# %%
def animate_tensor(tensor, N, save_path):
    global im
    global display_tensor
    display_tensor = tensor
    fig = plt.figure()
    im = plt.imshow(display_tensor[0], cmap=plt.get_cmap("gray"), animated = True)
    ani = FuncAnimation(fig, animate, interval = 100, frames = N, blit=True)
    plt.show()
    ani.save(save_path)

def animate(i):
    global im
    im.set_array(display_tensor[i])
    return im,

animate_tensor(tensor, N, "adj_mat_bin.gif")
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
fig, ax = plt.subplots()
def animate(i):
    ax.clear()
    nx.draw_circular(nx.from_numpy_matrix(tensor[i]), node_size=50, with_labels=True) #, with_labels=True, node_color=color_map
ani = FuncAnimation(fig, animate, frames = len(tensor), interval=200)
ani.save("graph_bin.gif")
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
