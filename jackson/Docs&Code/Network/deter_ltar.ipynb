# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as la

sys.path.insert(0, '../../Libraries')
from ltar import LTAR, diff, invert_diff

# %%
tensor = np.load("deter_graph.npy")
shape = tensor.shape
N = shape[0]
print("Shape", shape)
# Out:
# Shape (2000, 10, 10)

# %%
xlim = 200
plot_tensor = tensor[:xlim]
norm = np.array([la.norm(adj) for adj in plot_tensor])
plt.plot(np.arange(len(plot_tensor)), norm)

# %%
plt.plot(la.norm(plot_tensor,axis=1))
# Out:
# [<matplotlib.lines.Line2D at 0x7f8ff5027280>,
#  <matplotlib.lines.Line2D at 0x7f8ff50273a0>,
#  <matplotlib.lines.Line2D at 0x7f8ff5027460>,
#  <matplotlib.lines.Line2D at 0x7f8ff5027520>,
#  <matplotlib.lines.Line2D at 0x7f8ff50275e0>,
#  <matplotlib.lines.Line2D at 0x7f8ff50276a0>,
#  <matplotlib.lines.Line2D at 0x7f8ff5027760>,
#  <matplotlib.lines.Line2D at 0x7f8ff5027820>,
#  <matplotlib.lines.Line2D at 0x7f8ff50278e0>,
#  <matplotlib.lines.Line2D at 0x7f8ff50279a0>]
